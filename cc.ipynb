# %%
import pandas as pd

# %%
pd.read_csv('creditCardFraud_28011964_120214.csv')
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
# ...

# %%
data = pd.read_csv('creditCardFraud_28011964_120214.csv')

# %%
data.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
data.head(15)
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0       50000    1          2         1   57     -1      0     -1      0
# 1       50000    1          1         2   37      0      0      0      0
# 2      500000    1          1         2   29      0      0      0      0
# 3      100000    2          2         2   23      0     -1     -1      0
# 4      140000    2          3         1   28      0      0      2      0
# 5       20000    1          3         2   35     -2     -2     -2     -2
# 6      200000    2          3         2   34      0      0      2      0
# 7      260000    2          1         2   51     -1     -1     -1     -1
# 8      630000    2          2         2   41     -1      0     -1     -1
# 9       70000    1          2         2   30      1      2      2      0
# 10     250000    1          1         2   29      0      0      0      0
# 11      50000    2          3         3   23      1      2      0      0
# ...

# %%
data.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(data, title = 'Pandas Profiling report')

# %%
# profile.to_widgets()

# %%
data.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
X = data.drop('default payment next month',axis=1)

# %%
X
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
# ...

# %%
y = data['default payment next month']

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 996     0
# 997     0
# 998     0
# 999     1
# 1000    1
# Name: default payment next month, Length: 1001, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
X_train.head()
# Out:
#      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 535     110000    2          2         1   40      1      2      2      2
# 696     400000    2          2         2   40     -2     -2     -2     -2
# 557     360000    2          2         2   52     -2     -2     -2     -2
# 643      80000    2          2         2   24      0      0      0      0
# 597      30000    1          3         1   59     -1     -1     -1     -1
#
#      PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 535      2  ...      95768      97004      99005     101213       600
# 696     -1  ...          0          0       1524          0      8235
# 557     -2  ...         -6        999        944         -3      2231
# 643      0  ...      66396      55639      56873      58390      3100
# 597     -1  ...        390        390        390       1320       390
#
#      PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
#preprocessing steps

# %%
from sklearn.preprocessing import StandardScaler

# %%
train_scaler = StandardScaler()
test_scaler = StandardScaler()

# %%
scaled_train_data = train_scaler.fit_transform(X_train)

# %%
scaled_test_data = train_scaler.transform(X_test)

# %%
scaled_test_data
# Out:
# array([[ 3.90610866e-01,  8.25028647e-01,  2.95598783e-01, ...,
#         -3.49325067e-01, -1.43421555e-01,  6.05428533e+00],
#        [ 1.45195043e+00,  8.25028647e-01, -1.01817359e+00, ...,
#         -3.01426447e-01, -1.07467759e-01, -2.00015371e-01],
#        [ 1.15610203e-02, -1.21207912e+00,  1.60937115e+00, ...,
#          2.14072913e-02, -2.05260044e-02,  3.70246991e-03],
#        ...,
#        [-2.15868887e-01, -1.21207912e+00, -1.01817359e+00, ...,
#         -2.23276065e-01, -2.12823452e-01, -1.39103737e-01],
#        [-8.22348640e-01, -1.21207912e+00,  1.60937115e+00, ...,
#         -2.92380577e-01, -2.45455746e-01, -2.00015371e-01],
#        [ 2.51329000e+00,  8.25028647e-01,  2.95598783e-01, ...,
#          4.94762473e+00, -2.54720987e-01,  1.90161937e+00]])

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
clf.fit(scaled_train_data, y_train)
# Out:
# GaussianNB()

# %%
y_pred = clf.predict(scaled_test_data)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7711442786069652

# %%
clf2 = GaussianNB(var_smoothing=0.5)

# %%
clf2.fit(scaled_train_data,y_train)
# Out:
# GaussianNB(var_smoothing=0.5)

# %%
y_pred = clf2.predict(scaled_test_data)

# %%
accuracy_score(y_pred,y_test) #that is why we are now taking var_smoothing as 0.5
# Out:
# 0.8159203980099502

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()

# %%
xgb_fit = xgb.fit(scaled_train_data,y_train)

# %%
y_pred_xgb = xgb.predict(scaled_test_data)

# %%
accuracy_score(y_test,y_pred_xgb)
# Out:
# 0.835820895522388

# %%
#using hyper parameter n

# %%
from sklearn.model_selection import GridSearchCV
param_grid_xgboost = { "n_estimators": [50,100, 130],
                        "max_depth": range(3,11,1),
                      "random_state":[0,50,100]
                     }

# Creating an object of the Grid Search class
grid= GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid_xgboost,verbose=3,cv=5,n_jobs=-1)

# %%
grid.fit(scaled_train_data,y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END max_depth=3, n_estimators=50, random_state=0;, score=0.794 total time=   0.0s
# [CV 3/5] END max_depth=3, n_estimators=50, random_state=0;, score=0.787 total time=   0.0s
# [CV 4/5] END max_depth=3, n_estimators=50, random_state=50;, score=0.769 total time=   0.0s
# [CV 2/5] END max_depth=3, n_estimators=50, random_state=0;, score=0.787 total time=   0.0s
# [CV 5/5] END max_depth=3, n_estimators=50, random_state=50;, score=0.744 total time=   0.1s
# [CV 1/5] END max_depth=3, n_estimators=50, random_state=100;, score=0.794 total time=   0.0s
# [CV 2/5] END max_depth=3, n_estimators=50, random_state=100;, score=0.787 total time=   0.0s
# [CV 3/5] END max_depth=3, n_estimators=50, random_state=100;, score=0.787 total time=   0.0s
# [CV 1/5] END max_depth=3, n_estimators=50, random_state=50;, score=0.794 total time=   0.0s
# ...

# %%
grid.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, random_state=0, ...)

# %%
grid.best_params_
# Out:
# {'max_depth': 7, 'n_estimators': 50, 'random_state': 0}

# %%
xgb_new=XGBClassifier(max_depth = 7, n_estimators = 50, random_state = 0)

# %%
y_pred4=xgb_new.fit(scaled_train_data,y_train).predict(scaled_test_data)

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.8208955223880597

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(max_depth=2, random_state=0)

# %%
y_pred_rfc=rfc.fit(scaled_train_data,y_train).predict(scaled_test_data)

# %%
accuracy_score(y_test,y_pred_rfc)
# Out:
# 0.8407960199004975

# %%
# so from the above conclusion we can say that the maximum accuracy score is comming from the random forest regressor

# %%
import pickle

# %%
pickle.dump(rfc,open('RandomForest.pkl','wb'))
